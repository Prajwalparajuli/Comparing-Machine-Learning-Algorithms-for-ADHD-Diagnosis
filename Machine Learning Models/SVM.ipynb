# %% [markdown]
# ## Support Vector Machine

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import math

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = 'all'

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Importing necessary files

# %%
# Loading the data
FC_data = pd.read_csv("C:/Users/prajw/Desktop/Undergrad Research/Datasets/Preprocessed FC/Merged_FC.csv", index_col = 0)
FC_data.index.name = "Subject ID"
FC_data.head()

FC_pheno_data = pd.read_csv("C:/Users/prajw/Desktop/Undergrad Research/Datasets/Preprocessed FC matrix with Pheno/FC_Merged.csv", index_col = 0)
FC_pheno_data.index.name = "Subject ID"
FC_pheno_data.head()

FC_PCA = pd.read_csv("C:/Users/prajw/Desktop/Undergrad Research/Datasets/Preprocessed FC matrix with PCA extracted data/PCA_feature.csv", index_col = 0)
FC_PCA.index.name = "Subject ID"
FC_PCA.head()

Reho = pd.read_csv("C:/Users/prajw/Desktop/Undergrad Research/Datasets/Preprocessed ReHo/All_ReHo.csv", index_col = 0)
Reho.index.name = "Subject ID"
Reho.head()

falff = pd.read_csv("C:/Users/prajw/Desktop/Undergrad Research/Datasets/Preprocessed fALFF/All_falff.csv", index_col = 0)
falff.index.name = "Subject ID"
falff.head()
# Out:
#             DX         0         1         2         3         4         5  \
# Subject ID
# 1018959      0  0.082767 -0.202121 -0.253291  0.143162 -0.212533  0.572503
# 1019436      3  0.216872 -0.055456  0.274632  0.057173  0.318357  0.334924
# 1043241      0 -0.060757  0.218841 -0.220541 -0.009787 -0.018797  0.102055
# 1266183      0 -0.063801  0.061519 -0.011792  0.016329  0.135984  0.164675
# 1535233      0  0.022708  0.380467  0.404897  0.422225  0.546707 -0.022366
#
#                    6         7         8  ...     17945     17946     17947  \
# Subject ID                                ...
# 1018959    -0.346531  0.010921  0.014705  ...  0.112687  0.171248 -0.073971
# 1019436    -0.285290 -0.093749  0.051842  ... -0.466976 -0.189028  0.048556
# 1043241    -0.207456 -0.332605  0.157679  ... -0.118490 -0.123154 -0.287799
# 1266183     0.174189 -0.108558 -0.031854  ... -0.256891 -0.414658 -0.549495
# 1535233     0.218834  0.274712  0.191838  ... -0.238173 -0.059068 -0.020537
# ...

# %%
FC_data['DX'] = FC_data['DX'].apply(lambda x: 1 if x > 0 else 0)
FC_pheno_data['DX'] = FC_pheno_data['DX'].apply(lambda x: 1 if x > 0 else 0)
FC_PCA['DX'] = FC_PCA['DX'].apply(lambda x: 1 if x > 0 else 0)
Reho['DX'] = Reho['DX'].apply(lambda x: 1 if x > 0 else 0)
falff['DX'] = falff['DX'].apply(lambda x: 1 if x > 0 else 0)

FC_data
FC_PCA
FC_pheno_data
Reho
falff
# Out:
#             DX         0         1         2         3         4         5  \
# Subject ID
# 1018959      0  0.082767 -0.202121 -0.253291  0.143162 -0.212533  0.572503
# 1019436      1  0.216872 -0.055456  0.274632  0.057173  0.318357  0.334924
# 1043241      0 -0.060757  0.218841 -0.220541 -0.009787 -0.018797  0.102055
# 1266183      0 -0.063801  0.061519 -0.011792  0.016329  0.135984  0.164675
# 1535233      0  0.022708  0.380467  0.404897  0.422225  0.546707 -0.022366
# ...         ..       ...       ...       ...       ...       ...       ...
# 5669389      0 -0.136454 -0.065583  0.017311  0.052200  0.460014  0.306935
# 6383713      1  0.004203 -0.314136 -0.223007  0.475450  0.595427  0.529921
# 6477085      0 -0.619545 -0.075170 -0.074883  0.100222  0.329930  0.071147
# 7994085      0 -0.298730  0.156669 -0.152175  0.284072  0.307652  0.079670
# 8191384      0  0.116118 -0.267212 -0.054718  0.098136  0.368004  0.280456
#
# ...

# %% [markdown]
# #### Using Cross Validation and training the model

# %% [markdown]
# ##### Hyperparameter Optimization with Grid Search (Support Vector Machine)
#
# In this section, we perform **hyperparameter tuning** on a **Support Vector Machine (SVM)** classifier using **GridSearchCV** from scikit-learn. The tuning is conducted on the *Functional Connectivity + Phenotypic* dataset to identify the best combination of model parameters and then apply the optimized model to other feature sets (FC, PCA, ReHo, and fALFF).
#
# ##### What is being done?
#
# - We use **GridSearchCV** to search over a defined range of SVM hyperparameters including:
#   - Regularization strength (`C`) — balances margin size vs classification error.
#   - Kernel type (`kernel`) — either `'linear'` or `'rbf'`.
#   - Kernel coefficient (`gamma`) — controls influence of support vectors in the `'rbf'` kernel.
# - An **SVM classifier** is used with class balancing enabled via `class_weight='balanced'`.
# - The search is performed over all combinations using **10-fold Stratified Cross-Validation** to ensure reliable model evaluation while preserving class distribution.
#
# ##### Why is this important?
#
# - SVMs are well-suited for **high-dimensional** data like fMRI-derived features, but their performance heavily depends on hyperparameter settings.
# - The right combination of `C` and `gamma` allows the model to separate classes effectively without overfitting.
# - Using **GridSearchCV** ensures thorough evaluation across combinations to select the most effective hyperparameters.
# - **StratifiedKFold** ensures each fold has the same proportion of ADHD and non-ADHD subjects, which is critical for balanced evaluation.
#
# ##### Expected Outcome
#
# - Identification of the **best-performing hyperparameters** for the SVM classifier.
# - Improved **f1-score** and generalization on unseen ADHD data by tuning model complexity and decision boundaries.
# - Deployment of the optimized SVM model across all feature types to determine which representation (FC, PCA, ReHo, fALFF) yields the best diagnostic performance.

# %%
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold, GridSearchCV, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, f1_score
import numpy as np

# Cross-validation setup
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=45)

# Define scoring metrics
scorings = {
    'accuracy': 'accuracy',
    'precision': 'precision_weighted',
    'recall': 'recall_weighted',
    'f1': 'f1_weighted'
}

# Define hyperparameter grid for SVM
param_grid_svm = {
     'C': [0.1, 1, 10, 100],
     'gamma': ['scale', 0.01, 0.001],
     'kernel': ['rbf'],
    'shrinking': [True, False],
     'tol': [1e-4, 1e-3, 1e-2],
    'max_iter': [-1],
    'class_weight': ['balanced']
}

# Container for storing SVM results
results_svm = []

# %% [markdown]
# #### Functional Connectivity

# %%
# Step 1: Prepare X and y
X_FC = FC_data.drop(columns="DX")
y_FC = FC_data["DX"]

# Step 2: Train-test split
X_train_FC, X_test_FC, y_train_FC, y_test_FC = train_test_split(
    X_FC, y_FC, test_size=0.2, stratify=y_FC, random_state=45
)

# Step 3: Feature scaling
scaler = StandardScaler()
X_trs_FC = scaler.fit_transform(X_train_FC)
X_tes_FC = scaler.transform(X_test_FC)

# Step 4: Initialize base SVM model
base_model = SVC(class_weight='balanced', probability=True)

# Step 5: Grid Search CV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid_svm,
    scoring=scorings,
    refit='f1',
    cv=cv,
    verbose=2,
    n_jobs=-1
)

# Step 6: Fit and evaluate
grid_search.fit(X_trs_FC, y_train_FC)
y_pred_FC = grid_search.best_estimator_.predict(X_tes_FC)

print("SVM - FC Only")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_FC, y_pred_FC, digits=4))

# Step 7: Save results
results_svm.append({
    'Dataset': 'SVM - FC Only',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_FC, y_pred_FC, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1',
#              scoring={'accuracy': 'accuracy', 'f1': 'f1_weighted',
#                       'precision': 'precision_weighted',
#                       'recall': 'recall_weighted'},
#              verbose=2)
# SVM - FC Only
# Best Params: {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.0001}
# Best CV F1 Score: 0.6247
# ...

# %% [markdown]
# #### Functional Connectivity with Phenotype

# %%
# Step 1: Prepare X and y
X_FC_pheno = FC_pheno_data.drop(columns="DX")
y_FC_pheno = FC_pheno_data["DX"]

# Step 2: Train-test split
X_train_FCp, X_test_FCp, y_train_FCp, y_test_FCp = train_test_split(
    X_FC_pheno, y_FC_pheno, test_size=0.2, stratify=y_FC_pheno, random_state=45
)

# Step 3: Feature scaling
scaler = StandardScaler()
X_trs_FCp = scaler.fit_transform(X_train_FCp)
X_tes_FCp = scaler.transform(X_test_FCp)

# Step 4: Initialize base SVM model
base_model = SVC(class_weight='balanced', probability=True)

# Step 5: Grid Search CV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid_svm,
    scoring=scorings,
    refit='f1',
    cv=cv,
    verbose=2,
    n_jobs=-1
)

# Step 6: Fit and evaluate
grid_search.fit(X_trs_FCp, y_train_FCp)
y_pred_FCp = grid_search.best_estimator_.predict(X_tes_FCp)

print("SVM - FC + Phenotype")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_FCp, y_pred_FCp, digits=4))

# Step 7: Save results
results_svm.append({
    'Dataset': 'SVM - FC + Phenotype',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_FCp, y_pred_FCp, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1',
#              scoring={'accuracy': 'accuracy', 'f1': 'f1_weighted',
#                       'precision': 'precision_weighted',
#                       'recall': 'recall_weighted'},
#              verbose=2)
# SVM - FC + Phenotype
# Best Params: {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.0001}
# Best CV F1 Score: 0.6346
# ...

# %% [markdown]
# #### PCA Functional Connectivity

# %%
# Step 1: Prepare X and y
X_PCA = FC_PCA.drop(columns=["DX"])
y_PCA = FC_PCA["DX"]

# Step 2: Train-test split
X_train_PCA, X_test_PCA, y_train_PCA, y_test_PCA = train_test_split(
    X_PCA, y_PCA, test_size=0.2, stratify=y_PCA, random_state=45
)

# Step 3: Feature scaling
scaler = StandardScaler()
X_trs_PCA = scaler.fit_transform(X_train_PCA)
X_tes_PCA = scaler.transform(X_test_PCA)

# Step 4: Initialize base SVM model
base_model = SVC(class_weight='balanced', probability=True)

# Step 5: Grid Search CV (or replace with RandomizedSearchCV or Optuna)
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid_svm,
    scoring=scorings,
    refit='f1',
    cv=cv,
    verbose=2,
    n_jobs=-1
)

# Step 6: Fit and evaluate
grid_search.fit(X_trs_PCA, y_train_PCA)
y_pred_PCA = grid_search.best_estimator_.predict(X_tes_PCA)

print("SVM - PCA-FC Only")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_PCA, y_pred_PCA, digits=4))

# Step 7: Save results
results_svm.append({
    'Dataset': 'SVM - PCA-FC Only',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_PCA, y_pred_PCA, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1',
#              scoring={'accuracy': 'accuracy', 'f1': 'f1_weighted',
#                       'precision': 'precision_weighted',
#                       'recall': 'recall_weighted'},
#              verbose=2)
# SVM - PCA-FC Only
# Best Params: {'C': 1, 'class_weight': 'balanced', 'gamma': 0.001, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.0001}
# Best CV F1 Score: 0.5274
# ...

# %% [markdown]
# #### ReHo

# %%
# Step 1: Prepare X and y
X_Reho = Reho.drop(columns=["DX", "ScanDir ID"])
y_Reho = Reho["DX"]

# Step 2: Train-test split
X_train_Reho, X_test_Reho, y_train_Reho, y_test_Reho = train_test_split(
    X_Reho, y_Reho, test_size=0.2, stratify=y_Reho, random_state=45
)

# Step 3: Feature scaling
scaler = StandardScaler()
X_trs_Reho = scaler.fit_transform(X_train_Reho)
X_tes_Reho = scaler.transform(X_test_Reho)

# Step 4: Initialize base SVM model
base_model = SVC(class_weight='balanced', probability=True)

# Step 5: Grid Search CV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid_svm,
    scoring=scorings,
    refit='f1',
    cv=cv,
    verbose=2,
    n_jobs=-1
)

# Step 6: Fit and evaluate
grid_search.fit(X_trs_Reho, y_train_Reho)
y_pred_Reho = grid_search.best_estimator_.predict(X_tes_Reho)

print("SVM - ReHo Only")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_Reho, y_pred_Reho, digits=4))

# Step 7: Save results
results_svm.append({
    'Dataset': 'SVM - ReHo Only',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_Reho, y_pred_Reho, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1',
#              scoring={'accuracy': 'accuracy', 'f1': 'f1_weighted',
#                       'precision': 'precision_weighted',
#                       'recall': 'recall_weighted'},
#              verbose=2)
# SVM - ReHo Only
# Best Params: {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.01}
# Best CV F1 Score: 0.5896
# ...

# %% [markdown]
# #### fALFF

# %%
# Step 1: Prepare X and y
X_falff = falff.drop(columns="DX")
y_falff = falff["DX"]

# Step 2: Train-test split
X_train_falff, X_test_falff, y_train_falff, y_test_falff = train_test_split(
    X_falff, y_falff, test_size=0.2, stratify=y_falff, random_state=45
)

# Step 3: Feature scaling
scaler = StandardScaler()
X_trs_falff = scaler.fit_transform(X_train_falff)
X_tes_falff = scaler.transform(X_test_falff)

# Step 4: Initialize base SVM model
base_model = SVC(class_weight='balanced', probability=True)

# Step 5: Grid Search CV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid_svm,
    scoring=scorings,
    refit='f1',
    cv=cv,
    verbose=2,
    n_jobs=-1
)

# Step 6: Fit and evaluate
grid_search.fit(X_trs_falff, y_train_falff)
y_pred_falff = grid_search.best_estimator_.predict(X_tes_falff)

print("SVM - fALFF Only")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_falff, y_pred_falff, digits=4))

# Step 7: Save results
results_svm.append({
    'Dataset': 'SVM - fALFF Only',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_falff, y_pred_falff, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1',
#              scoring={'accuracy': 'accuracy', 'f1': 'f1_weighted',
#                       'precision': 'precision_weighted',
#                       'recall': 'recall_weighted'},
#              verbose=2)
# SVM - fALFF Only
# Best Params: {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.0001}
# Best CV F1 Score: 0.5843
# ...

# %%
FC_pheno_data.columns
FC_pheno_data.shape
# Out:
# Index(['DX', 'ADHD Index', 'Inattentive', 'Hyper/Impulsive', 'Verbal IQ',
#        'Performance IQ', 'Full4 IQ', 'Med Status', '0', '1',
#        ...
#        '17945', '17946', '17947', '17948', '17949', '17950', '17951', '17952',
#        '17953', '17954'],
#       dtype='object', length=17963)
# (493, 17963)

# %% [markdown]
# #### Merging the phenotypic data with PCA, ReHo and fALFF

# %%
# Step 1: Select phenotype columns and keep index aligned
phenotype_cols = ['Inattentive', 'Hyper/Impulsive', 'Verbal IQ', 
                  'Performance IQ', 'Full4 IQ', 'Med Status']

# Extract phenotype subset from FC + Pheno data
pheno_subset = FC_pheno_data[phenotype_cols].copy()
pheno_subset.index.name = 'Subject ID'

# Step 2: Align indexes for merging
# ReHo needs 'ScanDir ID' as index
ReHo_cleaned = Reho.set_index('ScanDir ID')  # Only ReHo has ScanDir ID
fALFF_cleaned = falff.copy()                 # Already has Subject ID as index
PCA_cleaned = FC_PCA.copy()                  # Already has Subject ID as index

# Step 3: Merge with phenotype subset
ReHo_pheno = ReHo_cleaned.join(pheno_subset, how='inner')
fALFF_pheno = fALFF_cleaned.join(pheno_subset, how='inner')
PCA_pheno = PCA_cleaned.join(pheno_subset, how='inner')

# Step 4: Report shapes
print("Subjects in all merged datasets:", 
      len(set(ReHo_pheno.index) & set(fALFF_pheno.index) & set(PCA_pheno.index)))
print("ReHo+Pheno shape:", ReHo_pheno.shape)
print("fALFF+Pheno shape:", fALFF_pheno.shape)
print("PCA+Pheno shape:", PCA_pheno.shape)
# Out:
# Subjects in all merged datasets: 493
# ReHo+Pheno shape: (493, 197)
# fALFF+Pheno shape: (493, 197)
# PCA+Pheno shape: (493, 495)

# %% [markdown]
# ### Retraining the Model for new PCA, ReHo and fALFF data

# %% [markdown]
# #### PCA + Phenotype

# %%
# Step 1: Prepare X and y
X_PCApheno = PCA_pheno.drop(columns="DX")
y_PCApheno = PCA_pheno["DX"]

# Step 2: Train-test split
X_train_PCApheno, X_test_PCApheno, y_train_PCApheno, y_test_PCApheno = train_test_split(
    X_PCApheno, y_PCApheno, test_size=0.2, stratify=y_PCApheno, random_state=45
)

# Step 3: Feature scaling
scaler = StandardScaler()
X_trs_PCApheno = scaler.fit_transform(X_train_PCApheno)
X_tes_PCApheno = scaler.transform(X_test_PCApheno)

# Step 4: Initialize base SVM model
base_model = SVC(class_weight='balanced', probability=True)

# Step 5: Grid Search CV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid_svm,
    scoring='f1_weighted',
    refit='f1_weighted',
    cv=cv,
    verbose=2,
    n_jobs=-1
)

# Step 6: Fit and evaluate
grid_search.fit(X_trs_PCApheno, y_train_PCApheno)
y_pred_PCApheno = grid_search.best_estimator_.predict(X_tes_PCApheno)

print("SVM - PCA + Phenotype")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_PCApheno, y_pred_PCApheno, digits=4))

# Step 7: Save results
results_svm.append({
    'Dataset': 'SVM - PCA + Phenotype',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_PCApheno, y_pred_PCApheno, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1_weighted', scoring='f1_weighted', verbose=2)
# SVM - PCA + Phenotype
# Best Params: {'C': 1, 'class_weight': 'balanced', 'gamma': 0.001, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.0001}
# Best CV F1 Score: 0.7268
#               precision    recall  f1-score   support
#
#            0     0.7344    0.8545    0.7899        55
#            1     0.7714    0.6136    0.6835        44
#
# ...

# %% [markdown]
# #### ReHo + Phenotype

# %%
# ReHo + Phenotype
X_ReHopheno = ReHo_pheno.drop(columns="DX")
y_ReHopheno = ReHo_pheno["DX"]

X_train_ReHopheno, X_test_ReHopheno, y_train_ReHopheno, y_test_ReHopheno = train_test_split(
    X_ReHopheno, y_ReHopheno, test_size=0.2, stratify=y_ReHopheno, random_state=45
)

scaler = StandardScaler()
X_trs_ReHopheno = scaler.fit_transform(X_train_ReHopheno)
X_tes_ReHopheno = scaler.transform(X_test_ReHopheno)

grid_search.fit(X_trs_ReHopheno, y_train_ReHopheno)
y_pred_ReHopheno = grid_search.best_estimator_.predict(X_tes_ReHopheno)

print("SVM - ReHo + Phenotype")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_ReHopheno, y_pred_ReHopheno, digits=4))

results_svm.append({
    'Dataset': 'SVM - ReHo + Phenotype',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_ReHopheno, y_pred_ReHopheno, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1_weighted', scoring='f1_weighted', verbose=2)
# SVM - ReHo + Phenotype
# Best Params: {'C': 10, 'class_weight': 'balanced', 'gamma': 0.001, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.0001}
# Best CV F1 Score: 0.7380
#               precision    recall  f1-score   support
#
#            0     0.7258    0.8182    0.7692        55
#            1     0.7297    0.6136    0.6667        44
#
# ...

# %% [markdown]
# #### fALFF + Phenotype

# %%
# fALFF + Phenotype
X_fALFFpheno = fALFF_pheno.drop(columns="DX")
y_fALFFpheno = fALFF_pheno["DX"]

X_train_fALFFpheno, X_test_fALFFpheno, y_train_fALFFpheno, y_test_fALFFpheno = train_test_split(
    X_fALFFpheno, y_fALFFpheno, test_size=0.2, stratify=y_fALFFpheno, random_state=45
)

scaler = StandardScaler()
X_trs_fALFFpheno = scaler.fit_transform(X_train_fALFFpheno)
X_tes_fALFFpheno = scaler.transform(X_test_fALFFpheno)

grid_search.fit(X_trs_fALFFpheno, y_train_fALFFpheno)
y_pred_fALFFpheno = grid_search.best_estimator_.predict(X_tes_fALFFpheno)

print("SVM - fALFF + Phenotype")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_fALFFpheno, y_pred_fALFFpheno, digits=4))

results_svm.append({
    'Dataset': 'SVM - fALFF + Phenotype',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_fALFFpheno, y_pred_fALFFpheno, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1_weighted', scoring='f1_weighted', verbose=2)
# SVM - fALFF + Phenotype
# Best Params: {'C': 10, 'class_weight': 'balanced', 'gamma': 0.001, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001}
# Best CV F1 Score: 0.7347
#               precision    recall  f1-score   support
#
#            0     0.7414    0.7818    0.7611        55
#            1     0.7073    0.6591    0.6824        44
#
# ...

# %% [markdown]
# ### Another approach by combining the features into one feature

# %%
# Get common subject IDs as a list (not a set)
common_subjects = list(set(PCA_pheno.index) & set(ReHo_pheno.index) & set(fALFF_pheno.index))

# Subset all data to common subjects
Reho_df = ReHo_pheno.loc[common_subjects]
falff_df = fALFF_pheno.loc[common_subjects]
pca_df = PCA_pheno.loc[common_subjects]

# Merge the features (excluding duplicate DX columns)
merged_df = pd.concat([
    Reho_df.drop(columns=['DX']),
    pca_df.drop(columns=['DX']),
    falff_df.drop(columns=['DX']), 
], axis=1)

# Add DX back from FC_pheno_data
merged_df['DX'] = Reho_df['DX']

print(" Combined dataset shape:", merged_df.shape)
merged_df.head()
# Out:
#  Combined dataset shape: (493, 887)
#            ReHo_1    ReHo_2    ReHo_3    ReHo_4    ReHo_5    ReHo_6    ReHo_7  \
# 4265987 -0.014901 -0.011997  0.029400 -0.036450  0.024473  0.019330 -0.001187
# 2740232  0.000932  0.014932  0.003096 -0.011630 -0.009327 -0.001066  0.036161
# 2107404  0.003473  0.034557  0.005788  0.009993  0.030830  0.038790  0.020458
# 3170319 -0.006727 -0.005627  0.022665 -0.000660  0.004608  0.006967  0.026371
# 1511464 -0.021578 -0.030079  0.005730  0.008717  0.022646  0.052798  0.038714
#
#            ReHo_8    ReHo_9   ReHo_10  ...       187       188       189  \
# 4265987  0.036221 -0.034957  0.035506  ...  0.580241  0.567530  0.661255
# 2740232  0.020279 -0.032160 -0.019165  ...  0.608890  0.574750  0.831190
# 2107404  0.047837  0.014925  0.012310  ...  0.481742  0.293470  0.390280
# 3170319  0.020267 -0.025849 -0.002162  ...  0.442391  0.380466  0.533641
# 1511464  0.048740 -0.016462  0.008129  ...  0.558072  0.513315  0.553850
#
# ...

# %%
X_merged = merged_df.drop(columns="DX")
y_merged = merged_df["DX"]

X_train_merged, X_test_merged, y_train_merged, y_test_merged = train_test_split(
    X_merged, y_merged, test_size=0.2, stratify=y_merged, random_state=45
)

scaler = StandardScaler()
X_trs_merged = scaler.fit_transform(X_train_merged)
X_tes_merged = scaler.transform(X_test_merged)


# Step 4: Initialize base SVM model
base_model = SVC(class_weight='balanced', probability=True)

# Step 5: Grid Search CV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid_svm,
    scoring='f1_weighted',
    refit='f1_weighted',
    cv=cv,
    verbose=2,
    n_jobs=-1
)

grid_search.fit(X_trs_merged, y_train_merged)
y_pred_merged = grid_search.best_estimator_.predict(X_tes_merged)

print("SVM - fALFF + Phenotype")
print("Best Params:", grid_search.best_params_)
print(f"Best CV F1 Score: {grid_search.best_score_:.4f}")
print(classification_report(y_test_merged, y_pred_merged, digits=4))

results_svm.append({
    'Dataset': 'SVM - PCA + PeHo + fALFF + Phenotype',
    'Best Params': grid_search.best_params_,
    'CV F1': grid_search.best_score_,
    'Test F1': f1_score(y_test_merged, y_pred_merged, average='weighted')
})
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=45, shuffle=True),
#              estimator=SVC(class_weight='balanced', probability=True),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'class_weight': ['balanced'],
#                          'gamma': ['scale', 0.01, 0.001], 'kernel': ['rbf'],
#                          'max_iter': [-1], 'shrinking': [True, False],
#                          'tol': [0.0001, 0.001, 0.01]},
#              refit='f1_weighted', scoring='f1_weighted', verbose=2)
# SVM - fALFF + Phenotype
# Best Params: {'C': 10, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.0001}
# Best CV F1 Score: 0.7230
#               precision    recall  f1-score   support
#
#            0     0.6984    0.8000    0.7458        55
#            1     0.6944    0.5682    0.6250        44
#
# ...

# %%
results_df = pd.DataFrame(results_svm)
results_df
# Out:
#                                 Dataset  \
# 0                         SVM - FC Only
# 1                  SVM - FC + Phenotype
# 2                     SVM - PCA-FC Only
# 3                       SVM - ReHo Only
# 4                      SVM - fALFF Only
# 5                 SVM - PCA + Phenotype
# 6                SVM - ReHo + Phenotype
# 7               SVM - fALFF + Phenotype
# 8  SVM - PCA + PeHo + fALFF + Phenotype
#
#                                          Best Params     CV F1   Test F1
# 0  {'C': 1, 'class_weight': 'balanced', 'gamma': ...  0.624716  0.623552
# 1  {'C': 1, 'class_weight': 'balanced', 'gamma': ...  0.634598  0.646025
# 2  {'C': 1, 'class_weight': 'balanced', 'gamma': ...  0.527360  0.467291
# 3  {'C': 1, 'class_weight': 'balanced', 'gamma': ...  0.589633  0.543562
# 4  {'C': 1, 'class_weight': 'balanced', 'gamma': ...  0.584307  0.635052
# 5  {'C': 1, 'class_weight': 'balanced', 'gamma': ...  0.726798  0.742640
# ...
